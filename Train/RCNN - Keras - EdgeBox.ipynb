# %%
import os,cv2,keras
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import sys
import os

# %%
path = "Image"
label = "Label"

# %%
path = "Image"
i = "3.jpg"

img = cv2.imread(os.path.join(path,i))
df = pd.read_csv(os.path.join(label,i[:-4]+".csv"))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
for row in df.iterrows():
    x1 = int((row[1][0].split(" ")[0]).split(".")[0])
    y1 = int((row[1][0].split(" ")[1]).split(".")[0])
    x2 = int((row[1][0].split(" ")[2]).split(".")[0])
    y2 = int((row[1][0].split(" ")[3]).split(".")[0])
    cv2.rectangle(img,(x1,y1),(x2,y2),(0,255,0), 2)
plt.figure()
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
model = "model.yml"
cv2.setUseOptimized(True);
edge_detection = cv2.ximgproc.createStructuredEdgeDetection(model)

# %%
def get_boxes(img):
    rgb_im = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    edges = edge_detection.detectEdges(np.float32(rgb_im) / 255.0)

    orimap = edge_detection.computeOrientation(edges)
    edges = edge_detection.edgesNms(edges, orimap)

    edge_boxes = cv2.ximgproc.createEdgeBoxes()
    edge_boxes.setMaxBoxes(30) 
    return edge_boxes.getBoundingBoxes(edges, orimap)

# %%
img = cv2.imread(os.path.join(path,i))
boxes = get_boxes(img)
for b in boxes[0]:
    x, y, w, h = b
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 1, cv2.LINE_AA)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread(os.path.join(path,i))
detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml');
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY);
faces = detector.detectMultiScale(gray, 1.3, 5);
print(faces)
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# Out:
# [[325  87 150 150]]

# %%
train_images=[]
train_labels=[]

# %%
def get_iou(bb1, bb2):
    assert bb1['x1'] < bb1['x2']
    assert bb1['y1'] < bb1['y2']
    assert bb2['x1'] < bb2['x2']
    assert bb2['y1'] < bb2['y2']

    x_left = max(bb1['x1'], bb2['x1'])
    y_top = max(bb1['y1'], bb2['y1'])
    x_right = min(bb1['x2'], bb2['x2'])
    y_bottom = min(bb1['y2'], bb2['y2'])

    if x_right < x_left or y_bottom < y_top:
        return 0.0

    intersection_area = (x_right - x_left) * (y_bottom - y_top)

    bb1_area = (bb1['x2'] - bb1['x1']) * (bb1['y2'] - bb1['y1'])
    bb2_area = (bb2['x2'] - bb2['x1']) * (bb2['y2'] - bb2['y1'])

    iou = intersection_area / float(bb1_area + bb2_area - intersection_area)
    assert iou >= 0.0
    assert iou <= 1.0
    return iou

# %%
c = 0
for e,i in enumerate(os.listdir(label)):
    try:
        filename = i.split(".")[0]+".jpg"
        print(e,filename)
        image = cv2.imread(os.path.join(path,filename))
        df = pd.read_csv(os.path.join(label,i))
        gtvalues=[]
        for row in df.iterrows():
            x1 = int((row[1][0].split(" ")[0]).split(".")[0])
            y1 = int((row[1][0].split(" ")[1]).split(".")[0])
            x2 = int((row[1][0].split(" ")[2]).split(".")[0])
            y2 = int((row[1][0].split(" ")[3]).split(".")[0])
            gtvalues.append({"x1":x1,"x2":x2,"y1":y1,"y2":y2})
        boxes = get_boxes(image)[0]
        imout = image.copy()
        counter = 0
        falsecounter = 0
        flag = 0
        fflag = 0
        bflag = 0
        c += 1
        if c > 1000:
            break
        for e,result in enumerate(boxes):
            if e < 2000 and flag == 0:
                for gtval in gtvalues:
                    x,y,w,h = result
                    iou = get_iou(gtval,{"x1":x,"x2":x+w,"y1":y,"y2":y+h})
                    if counter < 30:
                        if iou > 0.70:
                            timage = imout[y:y+h,x:x+w]
                            resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
                            train_images.append(resized)
                            train_labels.append(1)
                            counter += 1
                    else :
                        fflag =1
                    if falsecounter <30:
                        if iou < 0.3:
                            timage = imout[y:y+h,x:x+w]
                            resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
                            train_images.append(resized)
                            train_labels.append(0)
                            falsecounter += 1
                    else :
                        bflag = 1
                if fflag == 1 and bflag == 1:
                    print("inside")
                    flag = 1
    except Exception as e:
        print(e)
        print("error in "+filename)
        continue
# Out:
# 0 0.jpg
# 1 1.jpg
# 2 10.jpg
# 3 1000.jpg
# 4 10002.jpg
# 5 10003.jpg
# 6 10004.jpg
# 7 10005.jpg
# 8 10006.jpg
# 9 10007.jpg
# 10 10009.jpg
# 11 1001.jpg
# 12 10011.jpg
# 13 10013.jpg
# 14 10014.jpg
# 15 10015.jpg
# 16 10016.jpg
# 17 10017.jpg
# 18 10019.jpg
# 19 10020.jpg
# 20 10021.jpg
# 21 10022.jpg
# 22 10023.jpg
# 23 10025.jpg
# 24 10029.jpg
# 25 10031.jpg
# 26 10032.jpg
>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000028035BA5730>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000028037C2FE50>
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x0000028037C2F0A0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000028034C617F0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000028035B8A3D0>
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x0000028037CD87C0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002803B3CB640>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000028035B98FA0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000028037C299D0>
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x0000028037CD87F0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002803CEE1550>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002803CEE1970>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002803CEE5730>
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x000002803CEEA160>

# %%
X= vggmodel.layers[-2].output

# %%
predictions = Dense(2, activation="softmax")(X)

# %%
model_final = Model(vggmodel.input,predictions)

# %%
from keras.optimizers import Adam
opt = Adam(lr=0.0001)

# %%
model_final.compile(loss = keras.losses.categorical_crossentropy, optimizer = opt, metrics=["accuracy"])

# %%
model_final.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense (Dense)                (None, 2)                 8194
# =================================================================
# Total params: 134,268,738
# Trainable params: 126,633,474
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

# %%
class MyLabelBinarizer(LabelBinarizer):
    def transform(self, y):
        Y = super().transform(y)
        if self.y_type_ == 'binary':
            return np.hstack((Y, 1-Y))
        else:
            return Y
    def inverse_transform(self, Y, threshold=None):
        if self.y_type_ == 'binary':
            return super().inverse_transform(Y[:, 0], threshold)
        else:
            return super().inverse_transform(Y, threshold)

# %%
lenc = MyLabelBinarizer()
Y =  lenc.fit_transform(y_new)

# %%
X_train, X_test , y_train, y_test = train_test_split(X_new,Y,test_size=0.10)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (21483, 224, 224, 3) (2388, 224, 224, 3) (21483, 2) (2388, 2)

# %%
trdata = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, rotation_range=90)
traindata = trdata.flow(x=X_train[:10000], y=y_train[:10000],batch_size=32)
tsdata = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, rotation_range=90)
testdata = tsdata.flow(x=X_test, y=y_test,batch_size=32)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
checkpoint = ModelCheckpoint("ieeercnn_vgg16_1.h5", monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_loss', min_delta=0, patience=100, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
hist = model_final.fit(traindata, steps_per_epoch= 10, epochs= 10, validation_data= testdata, validation_steps=2, callbacks=[checkpoint,early])
# Out:
# Epoch 1/10
# 10/10 [==============================] - ETA: 0s - loss: 0.0767 - accuracy: 0.9719
# Epoch 00001: val_loss improved from 0.00000 to 0.00000, saving model to ieeercnn_vgg16_1.h5
# 10/10 [==============================] - 7s 659ms/step - loss: 0.0767 - accuracy: 0.9719 - val_loss: 1.8440e-07 - val_accuracy: 1.0000
# Epoch 2/10
# 10/10 [==============================] - ETA: 0s - loss: 0.0868 - accuracy: 0.9875
# Epoch 00002: val_loss did not improve from 0.00000
# 10/10 [==============================] - 3s 325ms/step - loss: 0.0868 - accuracy: 0.9875 - val_loss: 0.1857 - val_accuracy: 0.9688
# Epoch 3/10
# 10/10 [==============================] - ETA: 0s - loss: 0.0180 - accuracy: 0.9937
# Epoch 00003: val_loss did not improve from 0.00000
# 10/10 [==============================] - 3s 324ms/step - loss: 0.0180 - accuracy: 0.9937 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 4/10
# 10/10 [==============================] - ETA: 0s - loss: 0.0477 - accuracy: 0.9906
# Epoch 00004: val_loss did not improve from 0.00000
# 10/10 [==============================] - 3s 331ms/step - loss: 0.0477 - accuracy: 0.9906 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 5/10
# 10/10 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9937
# Epoch 00005: val_loss did not improve from 0.00000
# 10/10 [==============================] - 3s 327ms/step - loss: 0.0265 - accuracy: 0.9937 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 6/10
# 10/10 [==============================] - ETA: 0s - loss: 0.0353 - accuracy: 0.9906
# Epoch 00006: val_loss improved from 0.00000 to 0.00000, saving model to ieeercnn_vgg16_1.h5
# 10/10 [==============================] - 7s 655ms/step - loss: 0.0353 - accuracy: 0.9906 - val_loss: 1.2480e-07 - val_accuracy: 1.0000
# Epoch 7/10
# 10/10 [==============================] - ETA: 0s - loss: 0.0177 - accuracy: 0.9906
# Epoch 00007: val_loss did not improve from 0.00000
# 10/10 [==============================] - 3s 345ms/step - loss: 0.0177 - accuracy: 0.9906 - val_loss: 0.3943 - val_accuracy: 0.9375
# Epoch 8/10
# 10/10 [==============================] - ETA: 0s - loss: 0.0654 - accuracy: 0.9875
# Epoch 00008: val_loss did not improve from 0.00000
# 10/10 [==============================] - 4s 352ms/step - loss: 0.0654 - accuracy: 0.9875 - val_loss: 0.0523 - val_accuracy: 0.9688
# Epoch 9/10
# 10/10 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9969
# Epoch 00009: val_loss did not improve from 0.00000
# 10/10 [==============================] - 3s 349ms/step - loss: 0.0195 - accuracy: 0.9969 - val_loss: 0.1299 - val_accuracy: 0.9844
# Epoch 10/10
# 10/10 [==============================] - ETA: 0s - loss: 0.0643 - accuracy: 0.9906
# Epoch 00010: val_loss did not improve from 0.00000
# 10/10 [==============================] - 3s 349ms/step - loss: 0.0643 - accuracy: 0.9906 - val_loss: 0.0407 - val_accuracy: 0.9844

# %%
import matplotlib.pyplot as plt
# plt.plot(hist.history["acc"])
# plt.plot(hist.history['val_acc'])
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title("model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Loss","Validation Loss"])
plt.show()
plt.savefig('chart loss.png')

# %%
model_final.save('my_model.h5')

# %%
print(y_test[139])
# Out:
# [1 0]

# %%
im = X_test[139]
plt.imshow(im)
img = np.expand_dims(im, axis=0)
out= model_final.predict(img)
if out[0][0] > out[0][1]:
    print("plane")
else:
    print("not plane")
# Out:
# plane

# %%
z=0
i = "6.jpg"
img = cv2.imread(os.path.join(path,i))
ss.setBaseImage(img)
ss.switchToSelectiveSearchFast()
ssresults = ss.process()
imout = img.copy()
for e,result in enumerate(ssresults):
    if e < 3000:
        x,y,w,h = result
        timage = imout[y:y+h,x:x+w]
        resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
        img = np.expand_dims(resized, axis=0)
        out= model_final.predict(img)
        if out[0][0] > 0.65:
            cv2.rectangle(imout, (x, y), (x+w, y+h), (0, 255, 0), 1, cv2.LINE_AA)  
            break
    else:
        break
plt.figure()
plt.imshow(cv2.cvtColor(imout, cv2.COLOR_BGR2RGB))

# %% [markdown]
# Load and Try

# %%
from keras.models import load_model

model_final= load_model('my_model.h5')
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model_final.to(device)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-8df6fe187547> in <module>
#      10 model_final= load_model('my_model.h5')
#      11 device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
# ---> 12 model_final.to(device)
#
# AttributeError: 'Functional' object has no attribute 'to'

# %%
import time

# %%
import os,cv2,keras
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
path = "Image"

model = "model.yml"
#cv2.setUseOptimized(True);
edge_detection = cv2.ximgproc.createStructuredEdgeDetection(model)

def get_boxes(img):
    rgb_im = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    edges = edge_detection.detectEdges(np.float32(rgb_im) / 255.0)

    orimap = edge_detection.computeOrientation(edges)
    edges = edge_detection.edgesNms(edges, orimap)

    edge_boxes = cv2.ximgproc.createEdgeBoxes()
    edge_boxes.setMaxBoxes(30) 
    return edge_boxes.getBoundingBoxes(edges, orimap)

# %%
i = "2.jpg"
a = time.time()
img = cv2.imread(os.path.join(path,i))
boxes = get_boxes(img)[0]
imout = img.copy()
for e,result in enumerate(boxes):
        x,y,w,h = result
        timage = imout[y:y+h,x:x+w]
        resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
        img = np.expand_dims(resized, axis=0)
        out= model_final.predict(img)
        if out[0][0] > 0.40:
            cv2.rectangle(imout, (x, y), (x+w, y+h), (0, 255, 0), 2, cv2.LINE_AA) 
            break
plt.figure()
plt.imshow(cv2.cvtColor(imout, cv2.COLOR_BGR2RGB))
b = time.time()
print(b-a)
# Out:
# 2.2449216842651367

# %%
a = time.time()
img = cv2.imread(os.path.join(path,i))
detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml');
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY);
faces = detector.detectMultiScale(gray, 1.3, 5);
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
b = time.time()
print(b-a)
# Out:
# 0.07186746597290039

# %%
# Import the required modules
import cv2
from IPython.display import clear_output
import time
import PIL.Image
from cStringIO import StringIO
import IPython.display
import numpy as np

#Use 'jpeg' instead of 'png' (~5 times faster)
def showarray(a, fmt='jpeg'):
    f = StringIO()
    PIL.Image.fromarray(a).save(f, fmt)
    IPython.display.display(IPython.display.Image(data=f.getvalue()))

def get_frame(cam):
    # Capture frame-by-frame
    ret, frame = cam.read()
    
    #flip image for natural viewing
    frame = cv2.flip(frame, 1)
    
    return frame

cam = cv2.VideoCapture(0)
try:
    while(True):
        t1 = time.time()
        
        # Capture frame-by-frame
        frame = get_frame(cam)

        # Convert the image from OpenCV BGR format to matplotlib RGB format
        # to display the image
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        showarray(frame)
        t2 = time.time()

        print("%f FPS" % (1/(t2-t1)))
        # Display the frame until new frame is available
        clear_output(wait=True)
except KeyboardInterrupt:
    cam.release()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-170-d80114213e0b> in <module>
#       4 import time
#       5 import PIL.Image
# ----> 6 from cStringIO import StringIO
#       7 import IPython.display
#       8 import numpy as np
#
# ModuleNotFoundError: No module named 'cStringIO'

# %%
frame
